# %%
#Bank Application using OOP(python):
import time
class Bank:
    bank_name = 'Axis Bank'
    #zero balance account
    def __init__(self,name,balace = 0.0):
        self.name = name
        self.bal = balace
    def deposit(self,amount):
        self.bal += amount
        print('total balance after credit is Rs. ',self.bal)
    def withdraw(self,amount):
        self.bal -= amount
        print('total balance after credit is Rs.',self.bal)
nm = input('Enter your name: ')
b = Bank(nm)
while True:
    print('-----------------------------------------------')
    print('Hello',nm,'Welcome to',Bank.bank_name)
    print('-----------------------------------------------')
    time.sleep(2)
    print('Which operation would you like to perform')
    time.sleep(2)
    print('1.Deposit\n2.Withdraw\n3.Current balance\n4.Exit')
    choice = input('Enter your choice: ')
    if choice == '1':
        print(nm,'You have selected credit option')
        amount = float(input('please enter amount in Rs.'))
        time.sleep(2)
        b.deposit(amount)
    elif choice == '2':
        print(nm,'You have selected debit option')
        amount = float(input('please enter amount in Rs.'))
        time.sleep(2)
        b.withdraw(amount)
    elif choice == '3':
        print(nm,'Please wait we are fetching your current balance')
        time.sleep(2)
        print('Your Current Balance is Rs.',b.bal)
    else:
        print(nm,'Thank you for your time')
        print('Visit Again....')
        exit()
# Out:
# Enter your name: som
# -----------------------------------------------
# Hello som Welcome to Axis Bank
# -----------------------------------------------
# Which operation would you like to perform
# 1.Deposit
# 2.Withdraw
# 3.Current balance
# 4.Exit
# Enter your choice: 1
# som You have selected credit option
# please enter amount in Rs.5000
# total balance after credit is Rs.  5000.0
# -----------------------------------------------
# Hello som Welcome to Axis Bank
# -----------------------------------------------
# Which operation would you like to perform
# 1.Deposit
# 2.Withdraw
# 3.Current balance
# 4.Exit
# Enter your choice: 2
# som You have selected debit option
# please enter amount in Rs.200
# total balance after credit is Rs. 4800.0
# -----------------------------------------------
# Hello som Welcome to Axis Bank
# -----------------------------------------------
# Which operation would you like to perform
# 1.Deposit
# 2.Withdraw
# 3.Current balance
# 4.Exit
# Enter your choice: 3
# som Please wait we are fetching your current balance
# Your Current Balance is Rs. 4800.0
# -----------------------------------------------
# Hello som Welcome to Axis Bank
# -----------------------------------------------
# Which operation would you like to perform
# 1.Deposit
# 2.Withdraw
# 3.Current balance
# 4.Exit
# Enter your choice: 4
# som Thank you for your time
# Visit Again....
# -----------------------------------------------
# Hello som Welcome to Axis Bank
# -----------------------------------------------
# Which operation would you like to perform
# 1.Deposit
# 2.Withdraw
# 3.Current balance
# 4.Exit
